# %% [markdown]
# Nama: Farhan Riyandi

# %% [markdown]
# NIM : 20190801181

# %% [markdown]
# Mata Kuliah: Data Mining

# %% [markdown]
# UAS

# %% [markdown]
# # Loading Data

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data = pd.read_csv("Wine.csv") 
data
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
data.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline  Customer_Segment
# 0   3.92     1065                 1
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
data.describe()
# Out:
#           Alcohol  Malic_Acid         Ash  Ash_Alcanity   Magnesium  \
# count  178.000000  178.000000  178.000000    178.000000  178.000000
# mean    13.000618    2.336348    2.366517     19.494944   99.741573
# std      0.811827    1.117146    0.274344      3.339564   14.282484
# min     11.030000    0.740000    1.360000     10.600000   70.000000
# 25%     12.362500    1.602500    2.210000     17.200000   88.000000
# 50%     13.050000    1.865000    2.360000     19.500000   98.000000
# 75%     13.677500    3.082500    2.557500     21.500000  107.000000
# max     14.830000    5.800000    3.230000     30.000000  162.000000
#
#        Total_Phenols  Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
#  13  Customer_Segment      178 non-null    int64
# dtypes: float64(11), int64(3)
# ...

# %%
data.isna().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# Customer_Segment        0
# dtype: int64

# %%
fig = plt.figure(figsize=(8,10)) 
for i in range(len(data.columns)): 
    fig.add_subplot(4,4,i+1) 
    sns.distplot(data.iloc[:,i], kde=True, hist=True) 
    plt.xlabel(data.columns[i]) 
plt.tight_layout() 
plt.show()
# Out:
# E:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# E:\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plt.figure(figsize=(10, 8)) 
mask = np.triu(np.ones_like(data.corr())) 
sns.heatmap(data.corr(), cmap="YlGnBu", annot=True, mask=mask);

# %%
fig = plt.figure(figsize=(10,10)) 
for i in range(len(data.columns)): 
    fig.add_subplot(4,4,i+1)
    sns.boxplot(y=data.iloc[:,i]) 
    plt.xlabel(data.columns[i]) 
plt.tight_layout() 
plt.show()

# %% [markdown]
# # Model cluster dengan k=2

# %%
from scipy.cluster.vq import whiten, kmeans, vq 
skala_data2 = whiten(data) 
print(skala_data2)
# Out:
# [[17.57782045  1.53500398  8.88247841 ...  5.53677584  3.39148583
#    1.29390401]
#  [16.30549754  1.5978404   7.82242955 ...  4.80230557  3.34371843
#    1.29390401]
#  [16.25608694  2.11848502  9.75976023 ...  4.47744372  3.77362508
#    1.29390401]
#  ...
#  [16.39196609  3.84199826  8.26107046 ...  2.20341079  2.65905227
#    3.88171202]
#  [16.26843959  2.32494755  8.66315796 ...  2.28815736  2.67497474
#    3.88171202]
#  [17.45429396  3.6804189  10.0156341  ...  2.2599085   1.78331649
#    3.88171202]]

# %%
skala_data2 = pd.DataFrame(skala_data2, columns=['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity','Magnesium', 'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols', 'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline', 'Customer_Segment'])
cluster_centers, distortion = kmeans(skala_data2, 2) 
skala_data2['label'], distortions_list = vq(skala_data2, cluster_centers)

# %%
labels2 = skala_data2['label'] 
skala2 = skala_data2.drop('label', axis=1) 
print(skala2.columns) 
print(labels2)
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
#        'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
#        'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline',
#        'Customer_Segment'],
#       dtype='object')
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    1
# 174    1
# 175    1
# 176    1
# 177    1
# Name: label, Length: 178, dtype: int32

# %%
from sklearn.decomposition import PCA 
model2 = PCA(n_components=2) 
model2.fit(skala2) 
X = model2.transform(skala2)

# %%
X_final2 = pd.DataFrame(X, columns=['X', 'Y']) 
X_final2.head()
# Out:
#           X         Y
# 0 -3.522934 -1.453098
# 1 -2.528858  0.330019
# 2 -2.785029 -1.036936
# 3 -3.922588 -2.768210
# 4 -1.407511 -0.867773

# %%
labels2 = pd.DataFrame(labels2, columns=['label']) 
dfs = [X_final2, labels2] 
final_df2 = pd.concat(dfs, axis=1) 
final_df2.head()
# Out:
#           X         Y  label
# 0 -3.522934 -1.453098      0
# 1 -2.528858  0.330019      0
# 2 -2.785029 -1.036936      0
# 3 -3.922588 -2.768210      0
# 4 -1.407511 -0.867773      0

# %%
plt.figure(figsize=(8, 8)) 
sns.scatterplot(x='X', y='Y', hue='label', data=final_df2);

# %% [markdown]
# # model cluster dengan menggunakan metode elbow

# %%
from scipy.cluster.vq import whiten, kmeans, vq 
skala_data = whiten(data) 
print(skala_data)
# Out:
# [[17.57782045  1.53500398  8.88247841 ...  5.53677584  3.39148583
#    1.29390401]
#  [16.30549754  1.5978404   7.82242955 ...  4.80230557  3.34371843
#    1.29390401]
#  [16.25608694  2.11848502  9.75976023 ...  4.47744372  3.77362508
#    1.29390401]
#  ...
#  [16.39196609  3.84199826  8.26107046 ...  2.20341079  2.65905227
#    3.88171202]
#  [16.26843959  2.32494755  8.66315796 ...  2.28815736  2.67497474
#    3.88171202]
#  [17.45429396  3.6804189  10.0156341  ...  2.2599085   1.78331649
#    3.88171202]]

# %%
distortions = [] 
num_clusters = range(2, 7) 
for i in num_clusters: 
    centroids, distortion = kmeans(skala_data, i) 
    distortions.append(distortion) 
elbow_df = pd.DataFrame({'num_clusters': num_clusters, 'distortions': distortions})
sns.lineplot(x='num_clusters', y='distortions', data=elbow_df) 
plt.show()

# %%
data.columns
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
#        'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
#        'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline',
#        'Customer_Segment'],
#       dtype='object')

# %%
skala_data = pd.DataFrame(skala_data, columns=['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity','Magnesium', 'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols', 'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline', 'Customer_Segment'])
cluster_centers, distortion = kmeans(skala_data, 3) 
skala_data['label'], distortions_list = vq(skala_data, cluster_centers)

# %%
labels = skala_data['label'] 
skala = skala_data.drop('label', axis=1) 
print(skala.columns) 
print(labels)
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
#        'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
#        'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline',
#        'Customer_Segment'],
#       dtype='object')
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 173    0
# 174    0
# 175    0
# 176    0
# 177    0
# Name: label, Length: 178, dtype: int32

# %%
from sklearn.decomposition import PCA 
model = PCA(n_components=2) 
model.fit(skala) 
X = model.transform(skala)

# %%
X_final = pd.DataFrame(X, columns=['X', 'Y']) 
X_final.head()
# Out:
#           X         Y
# 0 -3.522934 -1.453098
# 1 -2.528858  0.330019
# 2 -2.785029 -1.036936
# 3 -3.922588 -2.768210
# 4 -1.407511 -0.867773

# %%
labels = pd.DataFrame(labels, columns=['label']) 
dfs = [X_final, labels] 
final_df = pd.concat(dfs, axis=1) 
final_df.head()
# Out:
#           X         Y  label
# 0 -3.522934 -1.453098      2
# 1 -2.528858  0.330019      2
# 2 -2.785029 -1.036936      2
# 3 -3.922588 -2.768210      2
# 4 -1.407511 -0.867773      2

# %%
plt.figure(figsize=(8, 8)) 
sns.scatterplot(x='X', y='Y', hue='label', data=final_df);
